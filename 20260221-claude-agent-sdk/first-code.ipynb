# %%
import asyncio
from typing import cast
from claude_agent_sdk import ClaudeSDKClient, ClaudeAgentOptions, AssistantMessage, TextBlock, ResultMessage

# %% [markdown]
# ### 単純な質問

# %%
client  = ClaudeSDKClient()
conn  = await client.connect()

async def message(text: str):
    yield text

await client.query("東京から金沢への行き方を教えて")
async for message in client.receive_response():
    print(message)
# Out:
# SystemMessage(subtype='init', data={'type': 'system', 'subtype': 'init', 'cwd': '/home/nnyn/ghq/github.com/74th/test-llm-agent/20260221-claude-agent-sdk', 'session_id': '58303ae5-2c2d-4edc-b7c3-378768a09c5d', 'tools': ['Task', 'TaskOutput', 'Bash', 'Glob', 'Grep', 'ExitPlanMode', 'Read', 'Edit', 'Write', 'NotebookEdit', 'WebFetch', 'TodoWrite', 'WebSearch', 'TaskStop', 'AskUserQuestion', 'Skill', 'EnterPlanMode'], 'mcp_servers': [], 'model': 'claude-sonnet-4-6', 'permissionMode': 'default', 'slash_commands': ['keybindings-help', 'debug', 'compact', 'context', 'cost', 'init', 'pr-comments', 'release-notes', 'review', 'security-review', 'insights'], 'apiKeySource': 'ANTHROPIC_API_KEY', 'claude_code_version': '2.1.49', 'output_style': 'default', 'agents': ['Bash', 'general-purpose', 'statusline-setup', 'Explore', 'Plan'], 'skills': ['keybindings-help', 'debug'], 'plugins': [], 'uuid': 'c42c21f8-6b41-4f80-b248-1c30951705f9', 'fast_mode_state': 'off'})
# AssistantMessage(content=[ThinkingBlock(thinking='The user is asking about how to get from Tokyo to Kanazawa in Japanese. Let me answer this question in Japanese.', signature='')], model='claude-sonnet-4-6', parent_tool_use_id=None, error=None)
# AssistantMessage(content=[TextBlock(text='## 東京から金沢への行き方\n\n主な移動手段をご紹介します。\n\n---\n\n### 🚄 北陸新幹線（おすすめ）\n\n**東京駅 → 金沢駅**\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **2時間30分** |\n| 料金 | 自由席 約 **14,000円** / 指定席 約 **14,580円** |\n| 列車名 | **かがやき**（速達）・**はくたか**（各駅） |\n| 運行頻度 | 1日複数本 |\n\n> ✅ **最速・最便利**な方法です。「かがやき」は途中停車駅が少なく最速です。\n\n---\n\n### 🚌 高速バス\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **7〜8時間** |\n| 料金 | 約 **3,000〜6,000円**（時期により変動） |\n| 乗り場 | 新宿・東京などのバスターミナル |\n\n> 💰 **コスト重視**の方向け。夜行バスなら宿泊費も節約できます。\n\n---\n\n### ✈️ 飛行機\n\n東京〜金沢間に直行便はありません（小松空港が最寄りですが、東京からの直行便は現在ほぼ運航していません）。\n\n---\n\n### 🚗 自動車\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **4〜5時間**（高速道路利用） |\n| ルート | 関越道・北陸道経由 |\n| 高速料金 | 約 **7,000〜9,000円** |\n\n---\n\n### 💡 まとめ\n\n| 優先事項 | おすすめ手段 |\n|---------|------------|\n| 速さ | 北陸新幹線「かがやき」 |\n| 安さ | 高速バス（夜行） |\n| 自由度 | レンタカー・マイカー |\n\n**北陸新幹線**が時間・快適さのバランスで最もおすすめです！')], model='claude-sonnet-4-6', parent_tool_use_id=None, error=None)
# ResultMessage(subtype='success', duration_ms=12677, duration_api_ms=12510, is_error=False, num_turns=1, session_id='58303ae5-2c2d-4edc-b7c3-378768a09c5d', total_cost_usd=0.02858425, usage={'input_tokens': 3, 'cache_creation_input_tokens': 505, 'cache_read_input_tokens': 15476, 'output_tokens': 707, 'server_tool_use': {'web_search_requests': 0, 'web_fetch_requests': 0}, 'service_tier': 'standard', 'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 505}, 'inference_geo': '', 'iterations': [], 'speed': 'standard'}, result='## 東京から金沢への行き方\n\n主な移動手段をご紹介します。\n\n---\n\n### 🚄 北陸新幹線（おすすめ）\n\n**東京駅 → 金沢駅**\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **2時間30分** |\n| 料金 | 自由席 約 **14,000円** / 指定席 約 **14,580円** |\n| 列車名 | **かがやき**（速達）・**はくたか**（各駅） |\n| 運行頻度 | 1日複数本 |\n\n> ✅ **最速・最便利**な方法です。「かがやき」は途中停車駅が少なく最速です。\n\n---\n\n### 🚌 高速バス\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **7〜8時間** |\n| 料金 | 約 **3,000〜6,000円**（時期により変動） |\n| 乗り場 | 新宿・東京などのバスターミナル |\n\n> 💰 **コスト重視**の方向け。夜行バスなら宿泊費も節約できます。\n\n---\n\n### ✈️ 飛行機\n\n東京〜金沢間に直行便はありません（小松空港が最寄りですが、東京からの直行便は現在ほぼ運航していません）。\n\n---\n\n### 🚗 自動車\n\n| 項目 | 詳細 |\n|------|------|\n| 所要時間 | 約 **4〜5時間**（高速道路利用） |\n| ルート | 関越道・北陸道経由 |\n| 高速料金 | 約 **7,000〜9,000円** |\n\n---\n\n### 💡 まとめ\n\n| 優先事項 | おすすめ手段 |\n|---------|------------|\n| 速さ | 北陸新幹線「かがやき」 |\n| 安さ | 高速バス（夜行） |\n| 自由度 | レンタカー・マイカー |\n\n**北陸新幹線**が時間・快適さのバランスで最もおすすめです！', structured_output=None)

# %% [markdown]
# ### Web検索

# %%
option = ClaudeAgentOptions(
    # model="claude-sonnet-4-5-20250929",
    model="claude-haiku-4-5-20251001",
    system_prompt="あなたは音声AIアシスタントのスタックチャンです。ユーザの質問に対して、3文程度の言葉で答えてください。音声案内であるため、マークダウンや絵文字等は用いずに、文字列だけで回答してください",
    cwd="/home/nnyn/ghq/github.com/74th/test-llm-agent/20260221-claude-agent-sdk/workspace",
    setting_sources=["project"],

)
client  = ClaudeSDKClient(
    options=option,
)
conn  = await client.connect()

async def message(text: str):
    yield text

await client.query("さいたま市の今日の天気は？")
async for message in client.receive_response():
    print(message)
# Out:
# SystemMessage(subtype='init', data={'type': 'system', 'subtype': 'init', 'cwd': '/home/nnyn/ghq/github.com/74th/test-llm-agent/20260221-claude-agent-sdk/workspace', 'session_id': 'b63ceb10-32b5-4ca4-8666-e1604ed444e2', 'tools': ['Task', 'TaskOutput', 'Bash', 'Glob', 'Grep', 'ExitPlanMode', 'Read', 'Edit', 'Write', 'NotebookEdit', 'WebFetch', 'TodoWrite', 'WebSearch', 'TaskStop', 'AskUserQuestion', 'Skill', 'EnterPlanMode'], 'mcp_servers': [], 'model': 'claude-haiku-4-5-20251001', 'permissionMode': 'default', 'slash_commands': ['keybindings-help', 'debug', 'compact', 'context', 'cost', 'init', 'pr-comments', 'release-notes', 'review', 'security-review', 'insights'], 'apiKeySource': 'ANTHROPIC_API_KEY', 'claude_code_version': '2.1.49', 'output_style': 'default', 'agents': ['Bash', 'general-purpose', 'statusline-setup', 'Explore', 'Plan'], 'skills': ['keybindings-help', 'debug'], 'plugins': [], 'uuid': '8d1e911b-dd43-4200-827f-943281d110e0', 'fast_mode_state': 'off'})
# AssistantMessage(content=[ThinkingBlock(thinking='ユーザーは「さいたま市の今日の天気は？」と日本語で質問しています。\n\nシステムメッセージから、私はスタックチャンという音声AIアシスタントであり、3文程度の言葉で答える必要があります。マークダウンや絵文字は用いずに、文字列だけで回答する必要があります。\n\n今日の日付は2026年2月21日です。\n\nさいたま市の天気情報を取得するには、WebSearchツールを使って現在の天気情報を検索する必要があります。\n\n天気情報を取得しましょう。', signature='...')], model='claude-haiku-4-5-20251001', parent_tool_use_id=None, error=None)
# AssistantMessage(content=[ToolUseBlock(id='toolu_01GHWUaAUndKFeFbMqnqf2BF', name='WebSearch', input={'query': 'さいたま市 天気 2026年2月21日'})], model='claude-haiku-4-5-20251001', parent_tool_use_id=None, error=None)
# UserMessage(content=[ToolResultBlock(tool_use_id='toolu_01GHWUaAUndKFeFbMqnqf2BF', content='Web search results for query: "さいたま市 天気 2026年2月21日"\n\nLinks: [{"title":"さいたま新都心の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com","url":"https://www.toshin.com/weather/detail?id=56459"},{"title":"さいたま市大宮区の天気 - Yahoo!天気・災害","url":"https://weather.yahoo.co.jp/weather/jp/11/4310/11103.html"},{"title":"埼玉県さいたま市の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com","url":"https://www.toshin.com/weather/detail?id=79327"},{"title":"さいたま市見沼区の天気 - Yahoo!天気・災害","url":"https://weather.yahoo.co.jp/weather/jp/11/4310/11104.html"},{"title":"南部（さいたま）の天気 - Yahoo!天気・災害","url":"https://weather.yahoo.co.jp/weather/jp/11/4310.html"},{"title":"さいたま市緑区の天気 - Yahoo!天気・災害","url":"https://weather.yahoo.co.jp/weather/jp/11/4310/11109.html"},{"title":"さいたま市浦和区の天気予報(1時間・今日明日・週間) - ウェザーニュース","url":"https://weathernews.jp/onebox/tenki/saitama/11107/"},{"title":"さいたま市の1時間天気 - 日本気象協会 tenki.jp","url":"https://tenki.jp/forecast/3/14/4310/11100/1hour.html"},{"title":"埼玉県さいたま市中央区の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com","url":"https://www.toshin.com/weather/detail?id=79332"},{"title":"さいたま市の2週間天気(旧:10日間天気) - 日本気象協会 tenki.jp","url":"https://tenki.jp/forecast/3/14/4310/11100/10days.html"}]\n\n2026年2月21日（土）のさいたま市の天気情報をお知らせします。\n\nさいたま市の天気は晴れで、最高気温は15℃、降水確率は0%です。気象情報は2月21日09時に発表されています。\n\n服装としては、セーターや厚手のジャケットなどがあるといいでしょう。\n\n\nREMINDER: You MUST include the sources above in your response to the user using markdown hyperlinks.', is_error=None)], uuid='4518041c-2379-4fa6-a505-bdf362fbcfc0', parent_tool_use_id=None, tool_use_result={'query': 'さいたま市 天気 2026年2月21日', 'results': [{'tool_use_id': 'srvtoolu_01YcUjXAk8yiwh3suewH6n7Q', 'content': [{'title': 'さいたま新都心の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com', 'url': 'https://www.toshin.com/weather/detail?id=56459'}, {'title': 'さいたま市大宮区の天気 - Yahoo!天気・災害', 'url': 'https://weather.yahoo.co.jp/weather/jp/11/4310/11103.html'}, {'title': '埼玉県さいたま市の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com', 'url': 'https://www.toshin.com/weather/detail?id=79327'}, {'title': 'さいたま市見沼区の天気 - Yahoo!天気・災害', 'url': 'https://weather.yahoo.co.jp/weather/jp/11/4310/11104.html'}, {'title': '南部（さいたま）の天気 - Yahoo!天気・災害', 'url': 'https://weather.yahoo.co.jp/weather/jp/11/4310.html'}, {'title': 'さいたま市緑区の天気 - Yahoo!天気・災害', 'url': 'https://weather.yahoo.co.jp/weather/jp/11/4310/11109.html'}, {'title': 'さいたま市浦和区の天気予報(1時間・今日明日・週間) - ウェザーニュース', 'url': 'https://weathernews.jp/onebox/tenki/saitama/11107/'}, {'title': 'さいたま市の1時間天気 - 日本気象協会 tenki.jp', 'url': 'https://tenki.jp/forecast/3/14/4310/11100/1hour.html'}, {'title': '埼玉県さいたま市中央区の今日・明日の天気｜2週間先までの1時間予報 - Toshin.com', 'url': 'https://www.toshin.com/weather/detail?id=79332'}, {'title': 'さいたま市の2週間天気(旧:10日間天気) - 日本気象協会 tenki.jp', 'url': 'https://tenki.jp/forecast/3/14/4310/11100/10days.html'}]}, '2026年2月21日（土）のさいたま市の天気情報をお知らせします。\n\nさいたま市の天気は晴れで、最高気温は15℃、降水確率は0%です。気象情報は2月21日09時に発表されています。\n\n服装としては、セーターや厚手のジャケットなどがあるといいでしょう。'], 'durationSeconds': 8.533250443})
# AssistantMessage(content=[ThinkingBlock(thinking='検索結果から、さいたま市の今日の天気についての情報が得られました。結果から、さいたま市の天気は晴れで、最高気温は15℃、降水確率は0%のようです。\n\nしかし、ユーザーはスタックチャンという音声AIアシスタントに対して質問しており、3文程度の言葉で答える必要があります。マークダウンや絵文字は用いずに、文字列だけで回答する必要があります。\n\nWebSearchの結果にはソースを含める必要があると言われていますが、この場合、音声案内ですので、マークダウンを使わずに文字列だけで回答する必要があります。\n\n3文程度で、さいたま市の天気について答えます。', signature='...')], model='claude-haiku-4-5-20251001', parent_tool_use_id=None, error=None)
# AssistantMessage(content=[TextBlock(text='さいたま市の今日の天気は晴れです。最高気温は15℃で、降水確率は0パーセントの予報となっています。セーターなど厚めの上着があると快適に過ごせるでしょう。')], model='claude-haiku-4-5-20251001', parent_tool_use_id=None, error=None)
# ResultMessage(subtype='success', duration_ms=14241, duration_api_ms=14229, is_error=False, num_turns=2, session_id='b63ceb10-32b5-4ca4-8666-e1604ed444e2', total_cost_usd=0.00728695, usage={'input_tokens': 18, 'cache_creation_input_tokens': 999, 'cache_read_input_tokens': 32502, 'output_tokens': 554, 'server_tool_use': {'web_search_requests': 0, 'web_fetch_requests': 0}, 'service_tier': 'standard', 'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 999}, 'inference_geo': '', 'iterations': [], 'speed': 'standard'}, result='さいたま市の今日の天気は晴れです。最高気温は15℃で、降水確率は0パーセントの予報となっています。セーターなど厚めの上着があると快適に過ごせるでしょう。', structured_output=None)
